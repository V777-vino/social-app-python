# %%
import social_app_functions as s
import Register_validation as v
import getpass
import re


def home():
    print("🎇 Welcome to Social app 🎇")
    print("\npress '1' for Sign up to create a New account")
    print("\npress '2' for Login")
    print("\npress '3' for Exit")
    num = int(input("\nEnter your choice:"))
    
    if(num==1):
        fname = input("\nEnter your first name:")
        lname = input("\nEnter your last name:")
        email = input("\nEnter your mail id:")
        phone_num = input("\nEnter your phone number:")
        gender = input("\nEnter the gender(M/F):")
        dob = input("\nEnter the date of birth(YYYY-MM-DD):")
        password = input("\nSet your password:")
        if(v.name_validation(fname) == True and s.is_registered(email)==True and v.name_validation(lname)== True and v.mail_validation(email)==True and v.phone_number_validation(phone_num) == True and v.gender_validation(gender) == True and v.password_validation(password) == True and v.is_valid_date(dob)==True):
            s.insert_user_details(fname,lname,email,phone_num,gender,dob,password)
            print("\nUser account created")
            print("==============================================")
        home()
    elif(num==2):
        mail = input("\nEnter the mail id:")
        password = input("\nEnter the password:")
        if(s.login(mail,password)==True):
            print("\nLogged in!!")
            print("=====================================================")
            menu()
        else:
            print("\nInvalid credentials...Try again!")
            print("=======================================================")
            home()
    elif(num==3):
        print("\nThanks for using Social app👍")
        print("=========================================================")
    else:
        print("\nPlease enter the valid choice")
        home()
def menu():
    print("\n=>Press '1' to see all posts")
    print("\n=>Press '2' for update mail")
    print("\n=>Press '3' for show user details by user id")
    print("\n=>Press '4' for update password")
    print("\n=>Press '5' for delete post")
    print("\n=>Press '6' for update phone number")
    print("\n=>Press '7' for delete user by user id")
    print("\n=>Press '8' to see your post by user id")
    print("\n=>Press '9' to post a message:")
    print("\n=>Press '10' for search user by their name")
    print("\n=>Press '11' fro Exit")
    choice = int(input("\nPlease Enter your choice:"))
    
    if(choice ==1):
        s.see_all_posts()
        menu()
    elif(choice==2):
        user_id = int(input("\nEnter your user id:"))
        mail = input("\nEnter your new mail id:")
        if(v.mail_validation(mail)==True):
            s.update_mail_id(user_id,mail)
        menu()
    elif(choice==3):
        user_id = int(input("\nEnter your user id:"))
        s.show_user_detail_by_id(user_id)
        menu()
    elif(choice==4):
        user_id = int(input("\nEnter your user id:"))
        password = getpass.getpass(prompt="Enter your password:")
        if(v.password_validation(password)==True):
            s.update_password(user_id,password)
        menu()
    elif(choice == 5):
        post_id = int(input("\nEnter your post id:"))
        s.delete_post(post_id)
        menu()
    elif(choice==6):
        user_id = int(input("\nEnter your user id:"))
        phone = input("\nEnter your new phone number:")
        if(v.phone_number_validation(phone)==True):
            s.update_phone_number(phone)
        menu()
    elif(choice ==7):
        user_id = int(input("\nEnter your user id:"))
        s.delete_user(user_id)
        menu()
    elif(choice==8):
        user_id = int(input("\nEnter your user id:"))
        s.your_posts(user_id)
        menu()
    elif(choice ==9):
        user_id = int(input("\nEnter your user id:"))
        post = input("\nEnter your message:")
        s.post_message(user_id,post)
        menu()
    elif(choice == 10):
        name = input("\nEnter the name:")
        s.search_user_by_name(name)
        menu()
    elif(choice == 11):
        print("\nExit")
        home()
    else:
        print("\nEnter the correct choice")
        menu()
        
        
home()
# Out:
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:2
#
# Enter the mail id:trisha@gmail.com
#
# Enter the password:Trisha@12345
#
# Logged in!!
# =====================================================
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:9
#
# Enter your user id:24
#
# Enter your message:Im in a leo movie shoot...too cool kashmir
#
# ***Your message posted***
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:8
#
# Enter your user id:24
#   post id    user id  message                                     posted date
# ---------  ---------  ------------------------------------------  -------------------
#         5         24  Im in a leo movie shoot...too cool kashmir  2023-04-15 19:15:35
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:1
#   user id  first name    message                                     posted date
# ---------  ------------  ------------------------------------------  -------------------
#         2  anto          you have to fight for your life             2023-04-14 23:29:16
#         8  revalika      I have a ego more than you!                 2023-04-14 23:43:08
#         1  antony        too hot chennai                             2023-04-14 23:45:06
#        24  trisha        Im in a leo movie shoot...too cool kashmir  2023-04-15 19:15:35
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:9
#
# Enter your user id:22
#
# Enter your message:Im new to revature
#
# ***Your message posted***
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:9
#
# Enter your user id:22
#
# Enter your message:I want to a data brick engineer..what should i do??
#
# ***Your message posted***
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:1
#   user id  first name    message                                              posted date
# ---------  ------------  ---------------------------------------------------  -------------------
#         2  anto          you have to fight for your life                      2023-04-14 23:29:16
#         8  revalika      I have a ego more than you!                          2023-04-14 23:43:08
#         1  antony        too hot chennai                                      2023-04-14 23:45:06
#        24  trisha        Im in a leo movie shoot...too cool kashmir           2023-04-15 19:15:35
#        22  rohit         Im new to revature                                   2023-04-15 19:16:47
#        22  rohit         I want to a data brick engineer..what should i do??  2023-04-15 19:17:50
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:9
#
# Enter your user id:12
#
# Enter your message:Miss cheidhunnanu
#
# ***This user id is not registered***
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:1
#   user id  first name    message                                              posted date
# ---------  ------------  ---------------------------------------------------  -------------------
#         2  anto          you have to fight for your life                      2023-04-14 23:29:16
#         8  revalika      I have a ego more than you!                          2023-04-14 23:43:08
#         1  antony        too hot chennai                                      2023-04-14 23:45:06
#        24  trisha        Im in a leo movie shoot...too cool kashmir           2023-04-15 19:15:35
#        22  rohit         Im new to revature                                   2023-04-15 19:16:47
#        22  rohit         I want to a data brick engineer..what should i do??  2023-04-15 19:17:50
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:11
#
# Exit
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:1
#
# Enter your first name:maria
#
# Enter your last name:p
#
# Enter your mail id:maria@gmail.com
#
# Enter your phone number:8925012905
#
# Enter the gender(M/F):F
#
# Enter the date of birth(YYYY-MM-DD):2000-05-12
#
# Set your password:Maria@1234
#
# ***Enter a valid name***
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:1
#
# Enter your first name:maria
#
# Enter your last name:p
#
# Enter your mail id:maria@gmail.com
#
# Enter your phone number:8925098235
#
# Enter the gender(M/F):F
#
# Enter the date of birth(YYYY-MM-DD):2000-05-21
#
# Set your password:Maria@123
#
# ***Enter a valid name***
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:1
#
# Enter your first name:maria
#
# Enter your last name:m
#
# Enter your mail id:maria@gmail.com
#
# Enter your phone number:8189882378
#
# Enter the gender(M/F):F
#
# Enter the date of birth(YYYY-MM-DD):2000-05-12
#
# Set your password:Maria@1234
#
# ***Enter a valid name***
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:1
#
# Enter your first name:maria
#
# Enter your last name:trainer
#
# Enter your mail id:maria@gmail.com
#
# Enter your phone number:8925082085
# Enter the gender(M/F):F
#
# Enter the date of birth(YYYY-MM-DD):2000-05-14
#
# Set your password:Maria@1234
#
# ***User account is created!***
#
# User account created
# ==============================================
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:2
#
# Enter the mail id:maria@gmail.com
#
# Enter the password:Maria@1234
#
# Logged in!!
# =====================================================
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:9
#
# Enter your user id:25
#
# Enter your message:Im taking a data bricks for rev students
#
# ***Your message posted***
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:1
#   user id  first name    message                                              posted date
# ---------  ------------  ---------------------------------------------------  -------------------
#         2  anto          you have to fight for your life                      2023-04-14 23:29:16
#         8  revalika      I have a ego more than you!                          2023-04-14 23:43:08
#         1  antony        too hot chennai                                      2023-04-14 23:45:06
#        24  trisha        Im in a leo movie shoot...too cool kashmir           2023-04-15 19:15:35
#        22  rohit         Im new to revature                                   2023-04-15 19:16:47
#        22  rohit         I want to a data brick engineer..what should i do??  2023-04-15 19:17:50
#        25  maria         Im taking a data bricks for rev students             2023-04-15 19:27:41
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:10
#
# Enter the name:m
# Name
# ------
# manoj
# mohmad
# maria
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:1
#   user id  first name    message                                              posted date
# ---------  ------------  ---------------------------------------------------  -------------------
#         2  anto          you have to fight for your life                      2023-04-14 23:29:16
#         8  revalika      I have a ego more than you!                          2023-04-14 23:43:08
#         1  antony        too hot chennai                                      2023-04-14 23:45:06
#        24  trisha        Im in a leo movie shoot...too cool kashmir           2023-04-15 19:15:35
#        22  rohit         Im new to revature                                   2023-04-15 19:16:47
#        22  rohit         I want to a data brick engineer..what should i do??  2023-04-15 19:17:50
#        25  maria         Im taking a data bricks for rev students             2023-04-15 19:27:41
#
# =>Press '1' to see all posts
#
# =>Press '2' for update mail
#
# =>Press '3' for show user details by user id
#
# =>Press '4' for update password
#
# =>Press '5' for delete post
#
# =>Press '6' for update phone number
#
# =>Press '7' for delete user by user id
#
# =>Press '8' to see your post by user id
#
# =>Press '9' to post a message:
#
# =>Press '10' for search user by their name
#
# =>Press '11' fro Exit
#
# Please Enter your choice:11
#
# Exit
# 🎇 Welcome to Social app 🎇
#
# press '1' for Sign up to create a New account
#
# press '2' for Login
#
# press '3' for Exit
#
# Enter your choice:1
#
# Enter your first name:joseph
#
# Enter your last name:vijay
#
# Enter your mail id:vijay@gmail.com
#
# Enter your phone number:8189880527
#
# Enter the gender(M/F):M
#
# Enter the date of birth(YYYY-MM-DD):2000-05-3
#
# Set your password:Vijay@1234
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in <module>
#     110
#     111
# --> 112 home()
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      31             print("\nLogged in!!")
#      32             print("=====================================================")
# ---> 33             menu()
#      34         else:
#      35             print("\nInvalid credentials...Try again!")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      97         post = input("\nEnter your message:")
#      98         s.post_message(user_id,post)
# ---> 99         menu()
#     100     elif(choice == 10):
#     101         name = input("\nEnter the name:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      92         user_id = int(input("\nEnter your user id:"))
#      93         s.your_posts(user_id)
# ---> 94         menu()
#      95     elif(choice ==9):
#      96         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      58     if(choice ==1):
#      59         s.see_all_posts()
# ---> 60         menu()
#      61     elif(choice==2):
#      62         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      97         post = input("\nEnter your message:")
#      98         s.post_message(user_id,post)
# ---> 99         menu()
#     100     elif(choice == 10):
#     101         name = input("\nEnter the name:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      97         post = input("\nEnter your message:")
#      98         s.post_message(user_id,post)
# ---> 99         menu()
#     100     elif(choice == 10):
#     101         name = input("\nEnter the name:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      58     if(choice ==1):
#      59         s.see_all_posts()
# ---> 60         menu()
#      61     elif(choice==2):
#      62         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      97         post = input("\nEnter your message:")
#      98         s.post_message(user_id,post)
# ---> 99         menu()
#     100     elif(choice == 10):
#     101         name = input("\nEnter the name:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      58     if(choice ==1):
#      59         s.see_all_posts()
# ---> 60         menu()
#      61     elif(choice==2):
#      62         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#     104     elif(choice == 11):
#     105         print("\nExit")
# --> 106         home()
#     107     else:
#     108         print("\nEnter the correct choice")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      24             print("\nUser account created")
#      25             print("==============================================")
# ---> 26         home()
#      27     elif(num==2):
#      28         mail = input("\nEnter the mail id:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      24             print("\nUser account created")
#      25             print("==============================================")
# ---> 26         home()
#      27     elif(num==2):
#      28         mail = input("\nEnter the mail id:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      24             print("\nUser account created")
#      25             print("==============================================")
# ---> 26         home()
#      27     elif(num==2):
#      28         mail = input("\nEnter the mail id:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      24             print("\nUser account created")
#      25             print("==============================================")
# ---> 26         home()
#      27     elif(num==2):
#      28         mail = input("\nEnter the mail id:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      31             print("\nLogged in!!")
#      32             print("=====================================================")
# ---> 33             menu()
#      34         else:
#      35             print("\nInvalid credentials...Try again!")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      97         post = input("\nEnter your message:")
#      98         s.post_message(user_id,post)
# ---> 99         menu()
#     100     elif(choice == 10):
#     101         name = input("\nEnter the name:")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      58     if(choice ==1):
#      59         s.see_all_posts()
# ---> 60         menu()
#      61     elif(choice==2):
#      62         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#     101         name = input("\nEnter the name:")
#     102         s.search_user_by_name(name)
# --> 103         menu()
#     104     elif(choice == 11):
#     105         print("\nExit")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#      58     if(choice ==1):
#      59         s.see_all_posts()
# ---> 60         menu()
#      61     elif(choice==2):
#      62         user_id = int(input("\nEnter your user id:"))
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in menu()
#     104     elif(choice == 11):
#     105         print("\nExit")
# --> 106         home()
#     107     else:
#     108         print("\nEnter the correct choice")
#
# ~\AppData\Local\Temp\ipykernel_4504\2539522289.py in home()
#      21         password = input("\nSet your password:")
#      22         if(v.name_validation(fname) == True and s.is_registered(email)==True and v.name_validation(lname)== True and v.mail_validation(email)==True and v.phone_number_validation(phone_num) == True and v.gender_validation(gender) == True and v.password_validation(password) == True and v.is_valid_date(dob)==True):
# ---> 23             s.insert_user_details(fname,lname,email,phone_num,gender,dob,password)
#      24             print("\nUser account created")
#      25             print("==============================================")
#
# ~\Social app\social_app_functions.py in insert_user_details(fname, lname, mail_id, phone_number, gender, dob, pword)
#      46     try:
#      47         cursor = conn.cursor()
# ---> 48         cursor.execute(query, args)
#      49         conn.commit()
#      50         print("\n***User account is created!***")
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     156         query = self.mogrify(query, args)
#     157
# --> 158         result = self._query(query)
#     159         self._executed = query
#     160         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     323         conn = self._get_db()
#     324         self._clear_result()
# --> 325         conn.query(q)
#     326         self._do_get_result()
#     327         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547             sql = sql.encode(self.encoding, "surrogateescape")
#     548         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550         return self._affected_rows
#     551
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     777         else:
#     778             result = MySQLResult(self)
# --> 779             result.read()
#     780         self._result = result
#     781         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1155     def read(self):
#    1156         try:
# -> 1157             first_packet = self.connection._read_packet()
#    1158
#    1159             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     727             if self._result is not None and self._result.unbuffered_active is True:
#     728                 self._result.unbuffered_active = False
# --> 729             packet.raise_for_error()
#     730         return packet
#     731
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '8189880527' for key 'users.phone_number'")
